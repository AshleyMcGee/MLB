# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

# %%
## Given a url which has all the links to games from a season, (e.g. 2014)
## Return a list of URLs for the games for scraping purposes
def get_games(url):
    response = requests.get(url)
    html = response.text
    
    # Create soup
    soup = BeautifulSoup(html, 'html.parser')
    
    # Base URL for concatenation
    base_url = 'https://www.baseball-reference.com'
    
    # Grab tags containing game ids from soup
    hrefs = soup.select('em a')

    # Build URLs in list comprehension
    game_ids = [base_url + hrefs[x]['href'] for x in range(len(hrefs))]

    return game_ids

## Given the raw HTML from a game page,
## Scrape the name of the umpire and return it
def get_ump(html):
    target_word = "Umpires:"
    word_len = len(target_word)
    start_idx = html.find(target_word) + word_len
    end_idx = start_idx + 100
    ump_name = html[start_idx: end_idx].split(',')[0].lstrip('</strong>').split('-')[1].strip(' ')
    return ump_name

# %%
## Here is an outline of how our for loop might work
## In this case, it is grabbing information for all the games from the 2014 season
games_2014_url = 'https://www.baseball-reference.com/leagues/MLB/2014-schedule.shtml'
games_2014 = get_games(games_2014_url)

df_list = []

for url in games_2014:
    # Load the html from the game page
    response = requests.get(url)
    html = response.text
    html = html.replace('<!--', '').replace('-->', '')

    # Find the umpire name for the game
    ump_name = get_ump(html)
    print(f'{ump_name}: {url}')
    
    # Do everything else here
    soup = BeautifulSoup(html, 'html.parser')

    pbp_table = soup.find('table', id='play_by_play')

    events = pbp_table.find_all('tr', {'class':['top_inning', 'bottom_inning']})
    
    for x in range(len(events)):
        try:
            x += 1
            if events[x].find(attrs={"data-stat": "batter"}).get_text() == events[x-1].find(attrs={"data-stat": "batter"}).get_text():
                events.pop(x-1)
                x -= 1
        except:
            break

        data_dict = {}
        pitch = []
        balls = []
        strikes = []
        count = []
        pitchers = []
        batters = []
        home_pitcher = []
        innings = []
        run_diffs = []
        umps = []

    for e in events:
        strike_codes = ['C', 'S', 'T', 'K', 'L', 'M', 'O', 'Q', 'R']
        foul_code = 'F'
        ball_codes = ['B', 'I', 'P', 'V']
        
        try:
            pit_seq = e.find('span', 'pitch_sequence').get_text()
            pit_seq = re.sub('[^CSFBXTKIHLMOPQRVY]', '', pit_seq)
            pit_seq = list(pit_seq)

            ball_count = 0
            strike_count = 0
            
            for pit in pit_seq:
                batter = e.find(attrs={"data-stat": "batter"}).get_text()
                pitcher = e.find(attrs={"data-stat": "pitcher"}).get_text()
                inning = e.find(attrs={"data-stat": "inning"}).get_text()
                score = e.find(attrs={"data-stat": "score_batting_team"}).get_text()

                ball_strike_count = f'{ball_count}-{strike_count}'
                
                bat_score, pit_score = score.split('-', 1)  
                run_diff = int(pit_score) - int(bat_score)
                
                top_bottom = list(inning)[0]
                
                if top_bottom == 't':
                    pitcher_home = 1
                else:
                    pitcher_home = 0
                    
                if len(list(inning)) > 2:
                    inning_num = int(list(inning)[1] + list(inning)[2])
                else:
                    inning_num = int(list(inning)[1])
                
                pitch.append(pit)
                balls.append(ball_count)
                strikes.append(strike_count)
                count.append(ball_strike_count)
                batters.append(batter)
                pitchers.append(pitcher)
                umps.append(ump_name)
                home_pitcher.append(pitcher_home)
                innings.append(inning_num)
                run_diffs.append(run_diff)
                
                if pit in strike_codes:
                    strike_count += 1
                elif pit == foul_code and strike_count < 2:
                    strike_count += 1
                elif pit in ball_codes:
                    ball_count += 1
                
        except Exception as exception:
            print(f'{exception}: {url}')
            pit_seq = None
    
    # Populate data dictionary and DataFrame
    data_dict["pitch"] = pitch
    data_dict["balls"] = balls
    data_dict["strikes"] = strikes
    data_dict["count"] = count
    data_dict["batter"] = batters
    data_dict["pitcher"] = pitchers
    data_dict["umpire"] = umps
    data_dict["home_pitcher"] = home_pitcher
    data_dict["inning"] = innings
    data_dict["run_diff"] = run_diffs

    df = pd.DataFrame(data_dict)
    
    df_list.append(df)
# Out:
# Tim Welke: https://www.baseball-reference.com/boxes/ARI/ARI201403220.shtml
# Dale Scott: https://www.baseball-reference.com/boxes/ARI/ARI201403230.shtml
# Fieldin Culbreth: https://www.baseball-reference.com/boxes/SDN/SDN201403300.shtml
# Joe West: https://www.baseball-reference.com/boxes/ANA/ANA201403310.shtml
# Tom Hallion: https://www.baseball-reference.com/boxes/ARI/ARI201403310.shtml
# Dana DeMuth: https://www.baseball-reference.com/boxes/BAL/BAL201403310.shtml
# Dale Scott: https://www.baseball-reference.com/boxes/CHA/CHA201403310.shtml
# Gary Cederstrom: https://www.baseball-reference.com/boxes/CIN/CIN201403310.shtml
# Jerry Meals: https://www.baseball-reference.com/boxes/DET/DET201403310.shtml
# Jerry Layne: https://www.baseball-reference.com/boxes/MIA/MIA201403310.shtml
# Ted Barrett: https://www.baseball-reference.com/boxes/MIL/MIL201403310.shtml
# Tim Welke: https://www.baseball-reference.com/boxes/NYN/NYN201403310.shtml
# Mike Winters: https://www.baseball-reference.com/boxes/OAK/OAK201403310.shtml
# John Hirschbeck: https://www.baseball-reference.com/boxes/PIT/PIT201403310.shtml
# Brian Gorman: https://www.baseball-reference.com/boxes/TBA/TBA201403310.shtml
# Jim Joyce: https://www.baseball-reference.com/boxes/TEX/TEX201403310.shtml
# Marty Foster: https://www.baseball-reference.com/boxes/ANA/ANA201404010.shtml
# Eric Cooper: https://www.baseball-reference.com/boxes/ARI/ARI201404010.shtml
# Gerry Davis: https://www.baseball-reference.com/boxes/HOU/HOU201404010.shtml
# Hunter Wendelstedt: https://www.baseball-reference.com/boxes/MIA/MIA201404010.shtml
# Greg Gibson: https://www.baseball-reference.com/boxes/MIL/MIL201404010.shtml
# Manny Gonzalez: https://www.baseball-reference.com/boxes/SDN/SDN201404010.shtml
# Bill Welke: https://www.baseball-reference.com/boxes/TBA/TBA201404010.shtml
# Doug Eddings: https://www.baseball-reference.com/boxes/TEX/TEX201404010.shtml
# Rob Drake: https://www.baseball-reference.com/boxes/ANA/ANA201404020.shtml
# Chris Guccione: https://www.baseball-reference.com/boxes/ARI/ARI201404020.shtml
# Ron Kulpa: https://www.baseball-reference.com/boxes/BAL/BAL201404020.shtml
# Dan Iassogna: https://www.baseball-reference.com/boxes/CHA/CHA201404020.shtml
# Kerwin Danley: https://www.baseball-reference.com/boxes/CIN/CIN201404020.shtml
# Paul Emmel: https://www.baseball-reference.com/boxes/DET/DET201404020.shtml
# Phil Cuzzi: https://www.baseball-reference.com/boxes/HOU/HOU201404020.shtml
# Mike DiMuro: https://www.baseball-reference.com/boxes/MIA/MIA201404020.shtml
# Paul Schrieber: https://www.baseball-reference.com/boxes/MIL/MIL201404020.shtml
# Clint Fagan: https://www.baseball-reference.com/boxes/NYN/NYN201404020.shtml
# Mark Wegner: https://www.baseball-reference.com/boxes/OAK/OAK201404021.shtml
# Andy Fletcher: https://www.baseball-reference.com/boxes/OAK/OAK201404022.shtml
# Bob Davidson: https://www.baseball-reference.com/boxes/PIT/PIT201404020.shtml
# Jim Reynolds: https://www.baseball-reference.com/boxes/SDN/SDN201404020.shtml
# Jim Wolf: https://www.baseball-reference.com/boxes/TBA/TBA201404020.shtml
# Marvin Hudson: https://www.baseball-reference.com/boxes/TEX/TEX201404020.shtml
# Pat Hoberg: https://www.baseball-reference.com/boxes/ARI/ARI201404030.shtml
# Ed Hickox: https://www.baseball-reference.com/boxes/BAL/BAL201404030.shtml
# CB Bucknor: https://www.baseball-reference.com/boxes/CHA/CHA201404030.shtml
# Lance Barksdale: https://www.baseball-reference.com/boxes/CIN/CIN201404030.shtml
# Brian Knight: https://www.baseball-reference.com/boxes/HOU/HOU201404030.shtml
# Mike Estabrook: https://www.baseball-reference.com/boxes/MIA/MIA201404030.shtml
# Tim Timmons: https://www.baseball-reference.com/boxes/NYN/NYN201404030.shtml
# Sean Barber: https://www.baseball-reference.com/boxes/OAK/OAK201404030.shtml
# James Hoye: https://www.baseball-reference.com/boxes/PIT/PIT201404030.shtml
# David Rackley: https://www.baseball-reference.com/boxes/TBA/TBA201404030.shtml
# Todd Tichenor: https://www.baseball-reference.com/boxes/BOS/BOS201404040.shtml
# Tripp Gibson: https://www.baseball-reference.com/boxes/CHN/CHN201404040.shtml
# Chris Conroy: https://www.baseball-reference.com/boxes/CLE/CLE201404040.shtml
# Mike Muchlinski: https://www.baseball-reference.com/boxes/COL/COL201404040.shtml
# Mark Ripperger: https://www.baseball-reference.com/boxes/DET/DET201404040.shtml
# Tom Hallion: https://www.baseball-reference.com/boxes/HOU/HOU201404040.shtml
# Will Little: https://www.baseball-reference.com/boxes/KCA/KCA201404040.shtml
# Alan Porter: https://www.baseball-reference.com/boxes/LAN/LAN201404040.shtml
# Quinn Wolcott: https://www.baseball-reference.com/boxes/MIA/MIA201404040.shtml
# John Tumpane: https://www.baseball-reference.com/boxes/NYN/NYN201404040.shtml
# Brian Gorman: https://www.baseball-reference.com/boxes/PIT/PIT201404040.shtml
# Jerry Layne: https://www.baseball-reference.com/boxes/TBA/TBA201404040.shtml
# Lance Barrett: https://www.baseball-reference.com/boxes/TOR/TOR201404040.shtml
# Cory Blaser: https://www.baseball-reference.com/boxes/WAS/WAS201404040.shtml
# Tim Welke: https://www.baseball-reference.com/boxes/BOS/BOS201404050.shtml
# Dale Scott: https://www.baseball-reference.com/boxes/CHN/CHN201404050.shtml
# Jordan Baker: https://www.baseball-reference.com/boxes/CLE/CLE201404050.shtml
# Mike Winters: https://www.baseball-reference.com/boxes/COL/COL201404050.shtml
# Gary Cederstrom: https://www.baseball-reference.com/boxes/DET/DET201404050.shtml
# Eric Cooper: https://www.baseball-reference.com/boxes/HOU/HOU201404050.shtml
# Ted Barrett: https://www.baseball-reference.com/boxes/KCA/KCA201404050.shtml
# Joe West: https://www.baseball-reference.com/boxes/LAN/LAN201404050.shtml
# Gerry Davis: https://www.baseball-reference.com/boxes/MIA/MIA201404050.shtml
# John Hirschbeck: https://www.baseball-reference.com/boxes/NYN/NYN201404050.shtml
# Fieldin Culbreth: https://www.baseball-reference.com/boxes/OAK/OAK201404050.shtml
# Jim Wolf: https://www.baseball-reference.com/boxes/PIT/PIT201404050.shtml
# Hunter Wendelstedt: https://www.baseball-reference.com/boxes/TBA/TBA201404050.shtml
# Dana DeMuth: https://www.baseball-reference.com/boxes/TOR/TOR201404050.shtml
# Jim Joyce: https://www.baseball-reference.com/boxes/WAS/WAS201404050.shtml
# Clint Fagan: https://www.baseball-reference.com/boxes/BOS/BOS201404060.shtml
# Dan Iassogna: https://www.baseball-reference.com/boxes/CHN/CHN201404060.shtml
# Jerry Meals: https://www.baseball-reference.com/boxes/CLE/CLE201404060.shtml
# Andy Fletcher: https://www.baseball-reference.com/boxes/COL/COL201404060.shtml
# Kerwin Danley: https://www.baseball-reference.com/boxes/DET/DET201404060.shtml
# Chris Guccione: https://www.baseball-reference.com/boxes/HOU/HOU201404060.shtml
# Greg Gibson: https://www.baseball-reference.com/boxes/KCA/KCA201404060.shtml
# Marty Foster: https://www.baseball-reference.com/boxes/LAN/LAN201404060.shtml
# Phil Cuzzi: https://www.baseball-reference.com/boxes/MIA/MIA201404060.shtml
# Bob Davidson: https://www.baseball-reference.com/boxes/NYN/NYN201404060.shtml
# Manny Gonzalez: https://www.baseball-reference.com/boxes/OAK/OAK201404060.shtml
# David Rackley: https://www.baseball-reference.com/boxes/PIT/PIT201404060.shtml
# Mike DiMuro: https://www.baseball-reference.com/boxes/TBA/TBA201404060.shtml
# Ron Kulpa: https://www.baseball-reference.com/boxes/TOR/TOR201404060.shtml
# Doug Eddings: https://www.baseball-reference.com/boxes/WAS/WAS201404060.shtml
# Paul Emmel: https://www.baseball-reference.com/boxes/BOS/BOS201404070.shtml
# Rob Drake: https://www.baseball-reference.com/boxes/COL/COL201404070.shtml
# Pat Hoberg: https://www.baseball-reference.com/boxes/HOU/HOU201404070.shtml
# Brian Knight: https://www.baseball-reference.com/boxes/KCA/KCA201404070.shtml
# Bill Miller: https://www.baseball-reference.com/boxes/MIN/MIN201404070.shtml
# Tim Timmons: https://www.baseball-reference.com/boxes/NYA/NYA201404070.shtml
# CB Bucknor: https://www.baseball-reference.com/boxes/SLN/SLN201404070.shtml
# Lance Barksdale: https://www.baseball-reference.com/boxes/ATL/ATL201404080.shtml
# Chris Conroy: https://www.baseball-reference.com/boxes/BOS/BOS201404080.shtml
# Jeff Nelson: https://www.baseball-reference.com/boxes/CHN/CHN201404080.shtml
# John Tumpane: https://www.baseball-reference.com/boxes/CLE/CLE201404080.shtml
# Alan Porter: https://www.baseball-reference.com/boxes/COL/COL201404080.shtml
# Quinn Wolcott: https://www.baseball-reference.com/boxes/KCA/KCA201404080.shtml
# Tom Hallion: https://www.baseball-reference.com/boxes/LAN/LAN201404080.shtml
# Todd Tichenor: https://www.baseball-reference.com/boxes/NYA/NYA201404080.shtml
# Larry Vanover: https://www.baseball-reference.com/boxes/PHI/PHI201404080.shtml
# Mike Muchlinski: https://www.baseball-reference.com/boxes/SEA/SEA201404080.shtml
# Jim Reynolds: https://www.baseball-reference.com/boxes/SFN/SFN201404080.shtml
# Tripp Gibson: https://www.baseball-reference.com/boxes/SLN/SLN201404080.shtml
# Mike Estabrook: https://www.baseball-reference.com/boxes/TOR/TOR201404080.shtml
# Jeff Kellogg: https://www.baseball-reference.com/boxes/WAS/WAS201404080.shtml
# Mark Ripperger: https://www.baseball-reference.com/boxes/ATL/ATL201404090.shtml
# Jordan Baker: https://www.baseball-reference.com/boxes/BOS/BOS201404090.shtml
# Laz Diaz: https://www.baseball-reference.com/boxes/CHN/CHN201404090.shtml
# Brian O'Nora: https://www.baseball-reference.com/boxes/CLE/CLE201404091.shtml
# James Hoye: https://www.baseball-reference.com/boxes/CLE/CLE201404092.shtml
# Joe West: https://www.baseball-reference.com/boxes/COL/COL201404090.shtml
# Gerry Davis: https://www.baseball-reference.com/boxes/KCA/KCA201404090.shtml
# Eric Cooper: https://www.baseball-reference.com/boxes/LAN/LAN201404090.shtml
# Vic Carapazza: https://www.baseball-reference.com/boxes/MIN/MIN201404090.shtml
# Tim Welke: https://www.baseball-reference.com/boxes/NYA/NYA201404090.shtml
# Angel Hernandez: https://www.baseball-reference.com/boxes/PHI/PHI201404090.shtml
# Mike Winters: https://www.baseball-reference.com/boxes/SEA/SEA201404090.shtml
# Sean Barber: https://www.baseball-reference.com/boxes/SFN/SFN201404090.shtml
# Dale Scott: https://www.baseball-reference.com/boxes/SLN/SLN201404090.shtml
# Jerry Layne: https://www.baseball-reference.com/boxes/TOR/TOR201404090.shtml
# Dan Bellino: https://www.baseball-reference.com/boxes/WAS/WAS201404090.shtml
# Gary Cederstrom: https://www.baseball-reference.com/boxes/ATL/ATL201404100.shtml
# Phil Cuzzi: https://www.baseball-reference.com/boxes/CHA/CHA201404100.shtml
# Mark Carlson: https://www.baseball-reference.com/boxes/CHN/CHN201404100.shtml
# Adam Hamari: https://www.baseball-reference.com/boxes/MIN/MIN201404100.shtml
# Bob Davidson: https://www.baseball-reference.com/boxes/NYA/NYA201404100.shtml
# Paul Nauert: https://www.baseball-reference.com/boxes/PHI/PHI201404100.shtml
# Fieldin Culbreth: https://www.baseball-reference.com/boxes/SFN/SFN201404100.shtml
# Hunter Wendelstedt: https://www.baseball-reference.com/boxes/TOR/TOR201404100.shtml
# Toby Basner: https://www.baseball-reference.com/boxes/WAS/WAS201404100.shtml
# Manny Gonzalez: https://www.baseball-reference.com/boxes/ANA/ANA201404110.shtml
# Will Little: https://www.baseball-reference.com/boxes/ARI/ARI201404110.shtml
# Adrian Johnson: https://www.baseball-reference.com/boxes/ATL/ATL201404110.shtml
# Jerry Meals: https://www.baseball-reference.com/boxes/BAL/BAL201404110.shtml
# Brian Knight: https://www.baseball-reference.com/boxes/CHA/CHA201404110.shtml
# D.J. Reyburn: https://www.baseball-reference.com/boxes/CIN/CIN201404110.shtml
# Greg Gibson: https://www.baseball-reference.com/boxes/MIL/MIL201404110.shtml
# Scott Barry: https://www.baseball-reference.com/boxes/MIN/MIN201404110.shtml
# James Hoye: https://www.baseball-reference.com/boxes/NYA/NYA201404110.shtml
# Kerwin Danley: https://www.baseball-reference.com/boxes/PHI/PHI201404110.shtml
# Andy Fletcher: https://www.baseball-reference.com/boxes/SDN/SDN201404110.shtml
# Chris Guccione: https://www.baseball-reference.com/boxes/SEA/SEA201404110.shtml
# Dan Iassogna: https://www.baseball-reference.com/boxes/SFN/SFN201404110.shtml
# Gabe Morales: https://www.baseball-reference.com/boxes/SLN/SLN201404110.shtml
# Marty Foster: https://www.baseball-reference.com/boxes/TEX/TEX201404110.shtml
# Sean Barber: https://www.baseball-reference.com/boxes/ANA/ANA201404120.shtml
# Tim Timmons: https://www.baseball-reference.com/boxes/ARI/ARI201404120.shtml
# Larry Vanover: https://www.baseball-reference.com/boxes/ATL/ATL201404120.shtml
# Paul Emmel: https://www.baseball-reference.com/boxes/BAL/BAL201404120.shtml
# Quinn Wolcott: https://www.baseball-reference.com/boxes/CHA/CHA201404120.shtml
# Clint Fagan: https://www.baseball-reference.com/boxes/CIN/CIN201404120.shtml
# Bill Miller: https://www.baseball-reference.com/boxes/MIL/MIL201404120.shtml
# Jeff Nelson: https://www.baseball-reference.com/boxes/MIN/MIN201404120.shtml
# John Tumpane: https://www.baseball-reference.com/boxes/NYA/NYA201404120.shtml
# Lance Barksdale: https://www.baseball-reference.com/boxes/PHI/PHI201404120.shtml
# Seth Buckminster: https://www.baseball-reference.com/boxes/SDN/SDN201404120.shtml
# Pat Hoberg: https://www.baseball-reference.com/boxes/SEA/SEA201404120.shtml
# Marvin Hudson: https://www.baseball-reference.com/boxes/SFN/SFN201404120.shtml
# Mike Estabrook: https://www.baseball-reference.com/boxes/SLN/SLN201404120.shtml
# Rob Drake: https://www.baseball-reference.com/boxes/TEX/TEX201404120.shtml
# Toby Basner: https://www.baseball-reference.com/boxes/ANA/ANA201404130.shtml
# Todd Tichenor: https://www.baseball-reference.com/boxes/ARI/ARI201404130.shtml
# Angel Hernandez: https://www.baseball-reference.com/boxes/ATL/ATL201404130.shtml
# Chris Conroy: https://www.baseball-reference.com/boxes/BAL/BAL201404130.shtml
# Gerry Davis: https://www.baseball-reference.com/boxes/CHA/CHA201404130.shtml
# Dan Bellino: https://www.baseball-reference.com/boxes/CIN/CIN201404130.shtml
# Vic Carapazza: https://www.baseball-reference.com/boxes/MIL/MIL201404130.shtml
# Laz Diaz: https://www.baseball-reference.com/boxes/MIN/MIN201404130.shtml
# Brian O'Nora: https://www.baseball-reference.com/boxes/NYA/NYA201404130.shtml
# Mark Ripperger: https://www.baseball-reference.com/boxes/PHI/PHI201404130.shtml
# Mike Muchlinski: https://www.baseball-reference.com/boxes/SDN/SDN201404130.shtml
# Tom Hallion: https://www.baseball-reference.com/boxes/SEA/SEA201404130.shtml
# Tripp Gibson: https://www.baseball-reference.com/boxes/SFN/SFN201404130.shtml
# Jerry Layne: https://www.baseball-reference.com/boxes/SLN/SLN201404130.shtml
# Alan Porter: https://www.baseball-reference.com/boxes/TEX/TEX201404130.shtml
# Tim Welke: https://www.baseball-reference.com/boxes/ANA/ANA201404140.shtml
# Hunter Wendelstedt: https://www.baseball-reference.com/boxes/ARI/ARI201404140.shtml
# Adam Hamari: https://www.baseball-reference.com/boxes/BAL/BAL201404140.shtml
# Phil Cuzzi: https://www.baseball-reference.com/boxes/CIN/CIN201404140.shtml
# Joe West: https://www.baseball-reference.com/boxes/MIA/MIA201404140.shtml
# Bob Davidson: https://www.baseball-reference.com/boxes/MIL/MIL201404140.shtml
# Bill Welke: https://www.baseball-reference.com/boxes/PHI/PHI201404140.shtml
# Scott Barry: https://www.baseball-reference.com/boxes/SDN/SDN201404140.shtml
# Paul Schrieber: https://www.baseball-reference.com/boxes/TEX/TEX201404140.shtml
# Chris Segal: https://www.baseball-reference.com/boxes/ANA/ANA201404150.shtml
# Gabe Morales: https://www.baseball-reference.com/boxes/ARI/ARI201404150.shtml
# Marvin Hudson: https://www.baseball-reference.com/boxes/CHA/CHA201404150.shtml
# Brian Knight: https://www.baseball-reference.com/boxes/CIN/CIN201404150.shtml
# Dale Scott: https://www.baseball-reference.com/boxes/HOU/HOU201404150.shtml
# Marty Foster: https://www.baseball-reference.com/boxes/MIA/MIA201404150.shtml
# James Hoye: https://www.baseball-reference.com/boxes/MIL/MIL201404150.shtml
# Eric Cooper: https://www.baseball-reference.com/boxes/MIN/MIN201404150.shtml
# Jeff Nelson: https://www.baseball-reference.com/boxes/SDN/SDN201404150.shtml
# Mike Winters: https://www.baseball-reference.com/boxes/SFN/SFN201404150.shtml
# Mark Carlson: https://www.baseball-reference.com/boxes/TEX/TEX201404150.shtml
# Tim Timmons: https://www.baseball-reference.com/boxes/ANA/ANA201404160.shtml
# Mike DiMuro: https://www.baseball-reference.com/boxes/ARI/ARI201404160.shtml
# Greg Gibson: https://www.baseball-reference.com/boxes/BAL/BAL201404160.shtml
# Cory Blaser: https://www.baseball-reference.com/boxes/CHA/CHA201404160.shtml
# Quinn Wolcott: https://www.baseball-reference.com/boxes/CIN/CIN201404160.shtml
# Ed Hickox: https://www.baseball-reference.com/boxes/DET/DET201404160.shtml
# Ron Kulpa: https://www.baseball-reference.com/boxes/HOU/HOU201404160.shtml
# Clint Fagan: https://www.baseball-reference.com/boxes/MIA/MIA201404160.shtml
# John Tumpane: https://www.baseball-reference.com/boxes/MIL/MIL201404160.shtml
# Jim Reynolds: https://www.baseball-reference.com/boxes/NYA/NYA201404161.shtml
# Fieldin Culbreth: https://www.baseball-reference.com/boxes/NYA/NYA201404162.shtml
# Brian Gorman: https://www.baseball-reference.com/boxes/PHI/PHI201404160.shtml
# Marcus Pattillo: https://www.baseball-reference.com/boxes/SDN/SDN201404160.shtml
# Andy Fletcher: https://www.baseball-reference.com/boxes/SFN/SFN201404160.shtml
# Ted Barrett: https://www.baseball-reference.com/boxes/TEX/TEX201404160.shtml
# Jim Joyce: https://www.baseball-reference.com/boxes/CHA/CHA201404170.shtml
# Lance Barrett: https://www.baseball-reference.com/boxes/DET/DET201404170.shtml
# CB Bucknor: https://www.baseball-reference.com/boxes/HOU/HOU201404170.shtml
# Chris Guccione: https://www.baseball-reference.com/boxes/MIN/MIN201404171.shtml
# Pat Hoberg: https://www.baseball-reference.com/boxes/MIN/MIN201404172.shtml
# Jim Wolf: https://www.baseball-reference.com/boxes/PHI/PHI201404170.shtml
# Manny Gonzalez: https://www.baseball-reference.com/boxes/PIT/PIT201404170.shtml
# Laz Diaz: https://www.baseball-reference.com/boxes/SDN/SDN201404170.shtml
# Seth Buckminster: https://www.baseball-reference.com/boxes/SFN/SFN201404170.shtml
# Rob Drake: https://www.baseball-reference.com/boxes/TBA/TBA201404170.shtml
# Will Little: https://www.baseball-reference.com/boxes/TEX/TEX201404170.shtml
# Bill Miller: https://www.baseball-reference.com/boxes/WAS/WAS201404170.shtml
# Paul Schrieber: https://www.baseball-reference.com/boxes/BOS/BOS201404180.shtml
# Doug Eddings: https://www.baseball-reference.com/boxes/CHN/CHN201404180.shtml
# Tripp Gibson: https://www.baseball-reference.com/boxes/CLE/CLE201404180.shtml
# Todd Tichenor: https://www.baseball-reference.com/boxes/COL/COL201404180.shtml
# Gerry Davis: https://www.baseball-reference.com/boxes/DET/DET201404180.shtml
# David Rackley: https://www.baseball-reference.com/boxes/KCA/KCA201404180.shtml
# Scott Barry: https://www.baseball-reference.com/boxes/LAN/LAN201404180.shtml
# Dana DeMuth: https://www.baseball-reference.com/boxes/MIA/MIA201404180.shtml
# Tom Hallion: https://www.baseball-reference.com/boxes/NYN/NYN201404180.shtml
# Mike Muchlinski: https://www.baseball-reference.com/boxes/OAK/OAK201404180.shtml
# Sean Barber: https://www.baseball-reference.com/boxes/PIT/PIT201404180.shtml
# Hunter Wendelstedt: https://www.baseball-reference.com/boxes/SDN/SDN201404180.shtml
# Joe West: https://www.baseball-reference.com/boxes/TBA/TBA201404180.shtml
# Jeff Kellogg: https://www.baseball-reference.com/boxes/TEX/TEX201404180.shtml
# Vic Carapazza: https://www.baseball-reference.com/boxes/WAS/WAS201404180.shtml
# Mark Carlson: https://www.baseball-reference.com/boxes/BOS/BOS201404190.shtml
# Marvin Hudson: https://www.baseball-reference.com/boxes/CHN/CHN201404190.shtml
# Dale Scott: https://www.baseball-reference.com/boxes/CLE/CLE201404190.shtml
# Tim Welke: https://www.baseball-reference.com/boxes/COL/COL201404190.shtml
# Phil Cuzzi: https://www.baseball-reference.com/boxes/DET/DET201404190.shtml
# Bill Welke: https://www.baseball-reference.com/boxes/KCA/KCA201404190.shtml
# Jeff Nelson: https://www.baseball-reference.com/boxes/LAN/LAN201404190.shtml
# Toby Basner: https://www.baseball-reference.com/boxes/MIA/MIA201404190.shtml
# Eric Cooper: https://www.baseball-reference.com/boxes/NYN/NYN201404190.shtml
# Mike Winters: https://www.baseball-reference.com/boxes/OAK/OAK201404190.shtml
# Jim Reynolds: https://www.baseball-reference.com/boxes/PIT/PIT201404190.shtml
# Gabe Morales: https://www.baseball-reference.com/boxes/SDN/SDN201404190.shtml
# Marty Foster: https://www.baseball-reference.com/boxes/TBA/TBA201404190.shtml
# Bob Davidson: https://www.baseball-reference.com/boxes/TEX/TEX201404190.shtml
# Adam Hamari: https://www.baseball-reference.com/boxes/WAS/WAS201404190.shtml
# Ted Barrett: https://www.baseball-reference.com/boxes/BOS/BOS201404200.shtml
# Cory Blaser: https://www.baseball-reference.com/boxes/CHN/CHN201404200.shtml
# Ron Kulpa: https://www.baseball-reference.com/boxes/CLE/CLE201404200.shtml
# Chris Segal: https://www.baseball-reference.com/boxes/COL/COL201404200.shtml
# Brian Knight: https://www.baseball-reference.com/boxes/DET/DET201404200.shtml
# Brian Gorman: https://www.baseball-reference.com/boxes/KCA/KCA201404200.shtml
# Marcus Pattillo: https://www.baseball-reference.com/boxes/LAN/LAN201404200.shtml
# Ed Hickox: https://www.baseball-reference.com/boxes/MIA/MIA201404200.shtml
# Mark Wegner: https://www.baseball-reference.com/boxes/NYN/NYN201404200.shtml
# Andy Fletcher: https://www.baseball-reference.com/boxes/OAK/OAK201404200.shtml
# Fieldin Culbreth: https://www.baseball-reference.com/boxes/PIT/PIT201404200.shtml
# Mike DiMuro: https://www.baseball-reference.com/boxes/SDN/SDN201404200.shtml
# Clint Fagan: https://www.baseball-reference.com/boxes/TBA/TBA201404200.shtml
# James Hoye: https://www.baseball-reference.com/boxes/TEX/TEX201404200.shtml
# Greg Gibson: https://www.baseball-reference.com/boxes/WAS/WAS201404200.shtml
# Jim Joyce: https://www.baseball-reference.com/boxes/ATL/ATL201404210.shtml
# Will Little: https://www.baseball-reference.com/boxes/BOS/BOS201404210.shtml
# D.J. Reyburn: https://www.baseball-reference.com/boxes/CHN/CHN201404210.shtml
# Bill Miller: https://www.baseball-reference.com/boxes/CLE/CLE201404210.shtml
# John Tumpane: https://www.baseball-reference.com/boxes/COL/COL201404210.shtml
# CB Bucknor: https://www.baseball-reference.com/boxes/DET/DET201404210.shtml
# Hunter Wendelstedt: https://www.baseball-reference.com/boxes/LAN/LAN201404210.shtml
# Tim Timmons: https://www.baseball-reference.com/boxes/MIL/MIL201404210.shtml
# Rob Drake: https://www.baseball-reference.com/boxes/NYN/NYN201404210.shtml
# Paul Nauert: https://www.baseball-reference.com/boxes/OAK/OAK201404210.shtml
# Gary Cederstrom: https://www.baseball-reference.com/boxes/PIT/PIT201404210.shtml
# Laz Diaz: https://www.baseball-reference.com/boxes/SEA/SEA201404210.shtml
# Jordan Baker: https://www.baseball-reference.com/boxes/WAS/WAS201404210.shtml
# Doug Eddings: https://www.baseball-reference.com/boxes/ATL/ATL201404220.shtml
# Quinn Wolcott: https://www.baseball-reference.com/boxes/BOS/BOS201404220.shtml
# Dan Bellino: https://www.baseball-reference.com/boxes/CHN/CHN201404220.shtml
# Vic Carapazza: https://www.baseball-reference.com/boxes/CLE/CLE201404220.shtml
# Bob Davidson: https://www.baseball-reference.com/boxes/COL/COL201404220.shtml
# Tripp Gibson: https://www.baseball-reference.com/boxes/DET/DET201404220.shtml
# Mike Estabrook: https://www.baseball-reference.com/boxes/LAN/LAN201404220.shtml
# Todd Tichenor: https://www.baseball-reference.com/boxes/MIL/MIL201404220.shtml
# Jeff Kellogg: https://www.baseball-reference.com/boxes/NYN/NYN201404220.shtml
# Adrian Johnson: https://www.baseball-reference.com/boxes/OAK/OAK201404220.shtml
# Kerwin Danley: https://www.baseball-reference.com/boxes/PIT/PIT201404220.shtml
# Scott Barry: https://www.baseball-reference.com/boxes/SEA/SEA201404220.shtml
# Paul Schrieber: https://www.baseball-reference.com/boxes/TBA/TBA201404220.shtml
# Seth Buckminster: https://www.baseball-reference.com/boxes/TOR/TOR201404220.shtml
# Jerry Meals: https://www.baseball-reference.com/boxes/WAS/WAS201404220.shtml
# Marvin Hudson: https://www.baseball-reference.com/boxes/ATL/ATL201404230.shtml
# Gerry Davis: https://www.baseball-reference.com/boxes/BOS/BOS201404230.shtml
# Tom Woodring: https://www.baseball-reference.com/boxes/CHN/CHN201404230.shtml
# Adam Hamari: https://www.baseball-reference.com/boxes/CLE/CLE201404230.shtml
# Chris Conroy: https://www.baseball-reference.com/boxes/COL/COL201404230.shtml
# Bill Welke: https://www.baseball-reference.com/boxes/DET/DET201404230.shtml
# Gabe Morales: https://www.baseball-reference.com/boxes/LAN/LAN201404230.shtml
# Tim Welke: https://www.baseball-reference.com/boxes/MIL/MIL201404230.shtml
# Marty Foster: https://www.baseball-reference.com/boxes/NYN/NYN201404230.shtml
# Larry Vanover: https://www.baseball-reference.com/boxes/OAK/OAK201404230.shtml
# Lance Barksdale: https://www.baseball-reference.com/boxes/PIT/PIT201404230.shtml
# Jeff Nelson: https://www.baseball-reference.com/boxes/SEA/SEA201404230.shtml
# Mark Carlson: https://www.baseball-reference.com/boxes/TBA/TBA201404230.shtml
# Mike Muchlinski: https://www.baseball-reference.com/boxes/TOR/TOR201404230.shtml
# Paul Emmel: https://www.baseball-reference.com/boxes/WAS/WAS201404230.shtml
# Phil Cuzzi: https://www.baseball-reference.com/boxes/BOS/BOS201404240.shtml
# Brian O'Nora: https://www.baseball-reference.com/boxes/CHN/CHN201404240.shtml
# Greg Gibson: https://www.baseball-reference.com/boxes/CLE/CLE201404240.shtml
# Dan Iassogna: https://www.baseball-reference.com/boxes/DET/DET201404240.shtml
# Toby Basner: https://www.baseball-reference.com/boxes/HOU/HOU201404240.shtml
# Mike DiMuro: https://www.baseball-reference.com/boxes/LAN/LAN201404240.shtml
# Alan Porter: https://www.baseball-reference.com/boxes/NYN/NYN201404240.shtml
# Mark Ripperger: https://www.baseball-reference.com/boxes/PIT/PIT201404240.shtml
# Ted Barrett: https://www.baseball-reference.com/boxes/TBA/TBA201404240.shtml
# Mike Winters: https://www.baseball-reference.com/boxes/TOR/TOR201404240.shtml
# Cory Blaser: https://www.baseball-reference.com/boxes/WAS/WAS201404240.shtml
# Mark Wegner: https://www.baseball-reference.com/boxes/ARI/ARI201404250.shtml
# Bill Miller: https://www.baseball-reference.com/boxes/ATL/ATL201404250.shtml
# Brian Knight: https://www.baseball-reference.com/boxes/BAL/BAL201404250.shtml
# Chris Segal: https://www.baseball-reference.com/boxes/CHA/CHA201404250.shtml
# Jordan Baker: https://www.baseball-reference.com/boxes/HOU/HOU201404250.shtml
# Angel Hernandez: https://www.baseball-reference.com/boxes/LAN/LAN201404250.shtml
# Gary Cederstrom: https://www.baseball-reference.com/boxes/MIL/MIL201404250.shtml
# D.J. Reyburn: https://www.baseball-reference.com/boxes/MIN/MIN201404250.shtml
# CB Bucknor: https://www.baseball-reference.com/boxes/NYA/NYA201404250.shtml
# Andy Fletcher: https://www.baseball-reference.com/boxes/NYN/NYN201404250.shtml
# Hunter Wendelstedt: https://www.baseball-reference.com/boxes/SEA/SEA201404250.shtml
# Marcus Pattillo: https://www.baseball-reference.com/boxes/SFN/SFN201404250.shtml
# Will Little: https://www.baseball-reference.com/boxes/SLN/SLN201404250.shtml
# Rob Drake: https://www.baseball-reference.com/boxes/TOR/TOR201404250.shtml
# Jim Joyce: https://www.baseball-reference.com/boxes/WAS/WAS201404250.shtml
# John Tumpane: https://www.baseball-reference.com/boxes/ARI/ARI201404260.shtml
# Vic Carapazza: https://www.baseball-reference.com/boxes/ATL/ATL201404260.shtml
# Quinn Wolcott: https://www.baseball-reference.com/boxes/BAL/BAL201404260.shtml
# Tim Timmons: https://www.baseball-reference.com/boxes/CHA/CHA201404260.shtml
# Jerry Meals: https://www.baseball-reference.com/boxes/HOU/HOU201404260.shtml
# Paul Nauert: https://www.baseball-reference.com/boxes/LAN/LAN201404260.shtml
# Kerwin Danley: https://www.baseball-reference.com/boxes/MIL/MIL201404260.shtml
# Dan Bellino: https://www.baseball-reference.com/boxes/MIN/MIN201404260.shtml
# Tripp Gibson: https://www.baseball-reference.com/boxes/NYA/NYA201404260.shtml
# Seth Buckminster: https://www.baseball-reference.com/boxes/NYN/NYN201404260.shtml
# Mike Estabrook: https://www.baseball-reference.com/boxes/SEA/SEA201404260.shtml
# Laz Diaz: https://www.baseball-reference.com/boxes/SFN/SFN201404260.shtml
# Paul Schrieber: https://www.baseball-reference.com/boxes/SLN/SLN201404260.shtml
# Jeff Kellogg: https://www.baseball-reference.com/boxes/TOR/TOR201404260.shtml
# Doug Eddings: https://www.baseball-reference.com/boxes/WAS/WAS201404260.shtml
# Bob Davidson: https://www.baseball-reference.com/boxes/ARI/ARI201404270.shtml
# Adam Hamari: https://www.baseball-reference.com/boxes/ATL/ATL201404270.shtml
# Jim Reynolds: https://www.baseball-reference.com/boxes/BAL/BAL201404270.shtml
# Adrian Johnson: https://www.baseball-reference.com/boxes/CHA/CHA201404270.shtml
# Paul Emmel: https://www.baseball-reference.com/boxes/HOU/HOU201404270.shtml
# Stu Scheurwater: https://www.baseball-reference.com/boxes/LAN/LAN201404270.shtml
# Lance Barksdale: https://www.baseball-reference.com/boxes/MIL/MIL201404270.shtml
# Bill Welke: https://www.baseball-reference.com/boxes/NYA/NYA201404270.shtml
# Mike Muchlinski: https://www.baseball-reference.com/boxes/NYN/NYN201404270.shtml
# Gabe Morales: https://www.baseball-reference.com/boxes/SEA/SEA201404270.shtml
# Scott Barry: https://www.baseball-reference.com/boxes/SFN/SFN201404270.shtml
# Mark Carlson: https://www.baseball-reference.com/boxes/SLN/SLN201404270.shtml
# Marty Foster: https://www.baseball-reference.com/boxes/TOR/TOR201404270.shtml
# Marvin Hudson: https://www.baseball-reference.com/boxes/WAS/WAS201404270.shtml
# Jim Wolf: https://www.baseball-reference.com/boxes/ANA/ANA201404280.shtml
# Lance Barrett: https://www.baseball-reference.com/boxes/ARI/ARI201404280.shtml
# Tim Welke: https://www.baseball-reference.com/boxes/CHA/CHA201404280.shtml
# Larry Vanover: https://www.baseball-reference.com/boxes/SFN/SFN201404280.shtml
# Toby Basner: https://www.baseball-reference.com/boxes/SLN/SLN201404280.shtml
# Jeff Nelson: https://www.baseball-reference.com/boxes/TEX/TEX201404280.shtml
# David Rackley: https://www.baseball-reference.com/boxes/ANA/ANA201404290.shtml
# Dana DeMuth: https://www.baseball-reference.com/boxes/ARI/ARI201404290.shtml
# Dan Iassogna: https://www.baseball-reference.com/boxes/BOS/BOS201404290.shtml
# Mike DiMuro: https://www.baseball-reference.com/boxes/CHA/CHA201404290.shtml
# Alan Porter: https://www.baseball-reference.com/boxes/CIN/CIN201404290.shtml
# Ted Barrett: https://www.baseball-reference.com/boxes/HOU/HOU201404290.shtml
# James Hoye: https://www.baseball-reference.com/boxes/KCA/KCA201404290.shtml
# Manny Gonzalez: https://www.baseball-reference.com/boxes/MIA/MIA201404290.shtml
# Greg Gibson: https://www.baseball-reference.com/boxes/NYA/NYA201404290.shtml
# Cory Blaser: https://www.baseball-reference.com/boxes/PHI/PHI201404290.shtml
# Angel Hernandez: https://www.baseball-reference.com/boxes/SFN/SFN201404290.shtml
# D.J. Reyburn: https://www.baseball-reference.com/boxes/SLN/SLN201404290.shtml
# Marcus Pattillo: https://www.baseball-reference.com/boxes/TEX/TEX201404290.shtml
# Gabe Morales: https://www.baseball-reference.com/boxes/ANA/ANA201404300.shtml
# Ron Kulpa: https://www.baseball-reference.com/boxes/ARI/ARI201404300.shtml
# Hunter Wendelstedt: https://www.baseball-reference.com/boxes/CHA/CHA201404300.shtml
# Rob Drake: https://www.baseball-reference.com/boxes/CIN/CIN201404300.shtml
# Paul Schrieber: https://www.baseball-reference.com/boxes/HOU/HOU201404300.shtml
# Mark Wegner: https://www.baseball-reference.com/boxes/KCA/KCA201404300.shtml
# Sean Barber: https://www.baseball-reference.com/boxes/MIA/MIA201404300.shtml
# Chris Segal: https://www.baseball-reference.com/boxes/MIN/MIN201404300.shtml
# Mark Ripperger: https://www.baseball-reference.com/boxes/SFN/SFN201404300.shtml
# Dan Bellino: https://www.baseball-reference.com/boxes/SLN/SLN201404300.shtml
# Laz Diaz: https://www.baseball-reference.com/boxes/TEX/TEX201404300.shtml
# Pat Hoberg: https://www.baseball-reference.com/boxes/BAL/BAL201405011.shtml
# Tom Hallion: https://www.baseball-reference.com/boxes/BAL/BAL201405012.shtml
# CB Bucknor: https://www.baseball-reference.com/boxes/BOS/BOS201405011.shtml
# Tripp Gibson: https://www.baseball-reference.com/boxes/BOS/BOS201405012.shtml
# Mike Estabrook: https://www.baseball-reference.com/boxes/CIN/CIN201405010.shtml
# Will Little: https://www.baseball-reference.com/boxes/COL/COL201405010.shtml
# John Tumpane: https://www.baseball-reference.com/boxes/KCA/KCA201405010.shtml
# Fieldin Culbreth: https://www.baseball-reference.com/boxes/MIA/MIA201405010.shtml
# Adrian Johnson: https://www.baseball-reference.com/boxes/MIN/MIN201405011.shtml
# Tim Timmons: https://www.baseball-reference.com/boxes/MIN/MIN201405012.shtml
# Bill Miller: https://www.baseball-reference.com/boxes/NYA/NYA201405010.shtml
# Ed Hickox: https://www.baseball-reference.com/boxes/ANA/ANA201405020.shtml
# Joe West: https://www.baseball-reference.com/boxes/ATL/ATL201405020.shtml
# Jeff Kellogg: https://www.baseball-reference.com/boxes/BOS/BOS201405020.shtml
# Paul Nauert: https://www.baseball-reference.com/boxes/CHN/CHN201405020.shtml
# Jerry Layne: https://www.baseball-reference.com/boxes/CIN/CIN201405020.shtml
# Eric Cooper: https://www.baseball-reference.com/boxes/CLE/CLE201405020.shtml
# Mark Carlson: https://www.baseball-reference.com/boxes/COL/COL201405020.shtml
# Bob Davidson: https://www.baseball-reference.com/boxes/HOU/HOU201405020.shtml
# Tim Welke: https://www.baseball-reference.com/boxes/KCA/KCA201405020.shtml
# Dale Scott: https://www.baseball-reference.com/boxes/MIA/MIA201405020.shtml
# Scott Barry: https://www.baseball-reference.com/boxes/MIN/MIN201405020.shtml
# Brian O'Nora: https://www.baseball-reference.com/boxes/NYA/NYA201405020.shtml
# Jim Reynolds: https://www.baseball-reference.com/boxes/PHI/PHI201405020.shtml
# Vic Carapazza: https://www.baseball-reference.com/boxes/PIT/PIT201405020.shtml
# Brian Gorman: https://www.baseball-reference.com/boxes/SDN/SDN201405020.shtml
# Lance Barrett: https://www.baseball-reference.com/boxes/ANA/ANA201405030.shtml
# Clint Fagan: https://www.baseball-reference.com/boxes/ATL/ATL201405030.shtml
# D.J. Reyburn: https://www.baseball-reference.com/boxes/BOS/BOS201405030.shtml
# Larry Vanover: https://www.baseball-reference.com/boxes/CHN/CHN201405030.shtml
# Mike DiMuro: https://www.baseball-reference.com/boxes/CIN/CIN201405030.shtml
# Chris Guccione: https://www.baseball-reference.com/boxes/CLE/CLE201405030.shtml
# Ted Barrett: https://www.baseball-reference.com/boxes/COL/COL201405030.shtml
# James Hoye: https://www.baseball-reference.com/boxes/HOU/HOU201405030.shtml
# Todd Tichenor: https://www.baseball-reference.com/boxes/KCA/KCA201405030.shtml
# Dan Iassogna: https://www.baseball-reference.com/boxes/MIA/MIA201405030.shtml
# Jeff Nelson: https://www.baseball-reference.com/boxes/MIN/MIN201405030.shtml
# Doug Eddings: https://www.baseball-reference.com/boxes/NYA/NYA201405030.shtml
# Manny Gonzalez: https://www.baseball-reference.com/boxes/PHI/PHI201405030.shtml
# Adam Hamari: https://www.baseball-reference.com/boxes/PIT/PIT201405030.shtml
# Jim Wolf: https://www.baseball-reference.com/boxes/SDN/SDN201405030.shtml
# Dana DeMuth: https://www.baseball-reference.com/boxes/ANA/ANA201405040.shtml
# Alan Porter: https://www.baseball-reference.com/boxes/ATL/ATL201405040.shtml
# Mark Ripperger: https://www.baseball-reference.com/boxes/BOS/BOS201405040.shtml
# Angel Hernandez: https://www.baseball-reference.com/boxes/CHN/CHN201405040.shtml
# Hunter Wendelstedt: https://www.baseball-reference.com/boxes/CIN/CIN201405040.shtml
# Pat Hoberg: https://www.baseball-reference.com/boxes/CLE/CLE201405040.shtml
# Paul Schrieber: https://www.baseball-reference.com/boxes/COL/COL201405040.shtml
# Mark Wegner: https://www.baseball-reference.com/boxes/HOU/HOU201405040.shtml
# Gabe Morales: https://www.baseball-reference.com/boxes/KCA/KCA201405040.shtml
# CB Bucknor: https://www.baseball-reference.com/boxes/MIA/MIA201405040.shtml
# Marcus Pattillo: https://www.baseball-reference.com/boxes/MIN/MIN201405040.shtml
# Marvin Hudson: https://www.baseball-reference.com/boxes/NYA/NYA201405040.shtml
# Sean Barber: https://www.baseball-reference.com/boxes/PHI/PHI201405040.shtml
# Greg Gibson: https://www.baseball-reference.com/boxes/PIT/PIT201405040.shtml
# David Rackley: https://www.baseball-reference.com/boxes/SDN/SDN201405040.shtml
# Laz Diaz: https://www.baseball-reference.com/boxes/ANA/ANA201405050.shtml
# Tim Timmons: https://www.baseball-reference.com/boxes/ATL/ATL201405050.shtml
# Jerry Meals: https://www.baseball-reference.com/boxes/CHN/CHN201405050.shtml
# Cory Blaser: https://www.baseball-reference.com/boxes/CLE/CLE201405050.shtml
# Gary Cederstrom: https://www.baseball-reference.com/boxes/COL/COL201405050.shtml
# Mike Winters: https://www.baseball-reference.com/boxes/DET/DET201405050.shtml
# Bill Miller: https://www.baseball-reference.com/boxes/MIA/MIA201405050.shtml
# Adrian Johnson: https://www.baseball-reference.com/boxes/MIL/MIL201405050.shtml
# Ron Kulpa: https://www.baseball-reference.com/boxes/OAK/OAK201405050.shtml
# Dan Bellino: https://www.baseball-reference.com/boxes/PHI/PHI201405050.shtml
# Phil Cuzzi: https://www.baseball-reference.com/boxes/PIT/PIT201405050.shtml
# Will Little: https://www.baseball-reference.com/boxes/SDN/SDN201405050.shtml
# John Tumpane: https://www.baseball-reference.com/boxes/WAS/WAS201405050.shtml
# Scott Barry: https://www.baseball-reference.com/boxes/ANA/ANA201405060.shtml
# Tim Welke: https://www.baseball-reference.com/boxes/ATL/ATL201405060.shtml
# Bill Welke: https://www.baseball-reference.com/boxes/BOS/BOS201405060.shtml
# Paul Emmel: https://www.baseball-reference.com/boxes/CHN/CHN201405060.shtml
# Brian O'Nora: https://www.baseball-reference.com/boxes/CLE/CLE201405060.shtml
# Kerwin Danley: https://www.baseball-reference.com/boxes/COL/COL201405060.shtml
# Andy Fletcher: https://www.baseball-reference.com/boxes/DET/DET201405060.shtml
# Vic Carapazza: https://www.baseball-reference.com/boxes/MIA/MIA201405060.shtml
# Toby Basner: https://www.baseball-reference.com/boxes/MIL/MIL201405060.shtml
# Ed Hickox: https://www.baseball-reference.com/boxes/OAK/OAK201405060.shtml
# Jeff Kellogg: https://www.baseball-reference.com/boxes/PHI/PHI201405060.shtml
# Quinn Wolcott: https://www.baseball-reference.com/boxes/PIT/PIT201405060.shtml
# Mark Carlson: https://www.baseball-reference.com/boxes/SDN/SDN201405060.shtml
# Joe West: https://www.baseball-reference.com/boxes/TBA/TBA201405060.shtml
# Paul Nauert: https://www.baseball-reference.com/boxes/WAS/WAS201405060.shtml
# Jeff Nelson: https://www.baseball-reference.com/boxes/ANA/ANA201405070.shtml
# Todd Tichenor: https://www.baseball-reference.com/boxes/ATL/ATL201405070.shtml
# Brian Gorman: https://www.baseball-reference.com/boxes/BOS/BOS201405070.shtml
# Tom Woodring: https://www.baseball-reference.com/boxes/CHA/CHA201405070.shtml
# Doug Eddings: https://www.baseball-reference.com/boxes/CLE/CLE201405070.shtml
# Seth Buckminster: https://www.baseball-reference.com/boxes/DET/DET201405070.shtml
# Adam Hamari: https://www.baseball-reference.com/boxes/MIA/MIA201405070.shtml
# Larry Vanover: https://www.baseball-reference.com/boxes/MIL/MIL201405070.shtml
# Lance Barrett: https://www.baseball-reference.com/boxes/OAK/OAK201405071.shtml
# Dana DeMuth: https://www.baseball-reference.com/boxes/OAK/OAK201405072.shtml
# Gerry Davis: https://www.baseball-reference.com/boxes/PIT/PIT201405070.shtml
# Ted Barrett: https://www.baseball-reference.com/boxes/SDN/SDN201405070.shtml
# Clint Fagan: https://www.baseball-reference.com/boxes/TBA/TBA201405070.shtml
# Lance Barksdale: https://www.baseball-reference.com/boxes/TEX/TEX201405070.shtml
# Tripp Gibson: https://www.baseball-reference.com/boxes/TOR/TOR201405070.shtml
# James Hoye: https://www.baseball-reference.com/boxes/WAS/WAS201405070.shtml
# Marvin Hudson: https://www.baseball-reference.com/boxes/CHA/CHA201405080.shtml
# Chris Segal: https://www.baseball-reference.com/boxes/CLE/CLE201405080.shtml
# Mike Muchlinski: https://www.baseball-reference.com/boxes/DET/DET201405080.shtml
# Paul Schrieber: https://www.baseball-reference.com/boxes/LAN/LAN201405080.shtml
# Ron Kulpa: https://www.baseball-reference.com/boxes/SDN/SDN201405080.shtml
# Marcus Pattillo: https://www.baseball-reference.com/boxes/SEA/SEA201405080.shtml
# Marty Foster: https://www.baseball-reference.com/boxes/TBA/TBA201405080.shtml
# Mark Ripperger: https://www.baseball-reference.com/boxes/TEX/TEX201405080.shtml
# D.J. Reyburn: https://www.baseball-reference.com/boxes/TOR/TOR201405080.shtml
# Mike Winters: https://www.baseball-reference.com/boxes/ATL/ATL201405090.shtml
# Dan Bellino: https://www.baseball-reference.com/boxes/BAL/BAL201405090.shtml
# Chris Conroy: https://www.baseball-reference.com/boxes/CHA/CHA201405090.shtml
# Cory Blaser: https://www.baseball-reference.com/boxes/CIN/CIN201405090.shtml
# Alan Porter: https://www.baseball-reference.com/boxes/DET/DET201405090.shtml
# Will Little: https://www.baseball-reference.com/boxes/LAN/LAN201405090.shtml
# Jerry Meals: https://www.baseball-reference.com/boxes/MIL/MIL201405090.shtml
# Gabe Morales: https://www.baseball-reference.com/boxes/NYN/NYN201405090.shtml
# Gary Cederstrom: https://www.baseball-reference.com/boxes/OAK/OAK201405090.shtml
# Jim Wolf: https://www.baseball-reference.com/boxes/PIT/PIT201405090.shtml
# Ed Hickox: https://www.baseball-reference.com/boxes/SDN/SDN201405090.shtml
# Laz Diaz: https://www.baseball-reference.com/boxes/SEA/SEA201405090.shtml
# Mark Wegner: https://www.baseball-reference.com/boxes/TBA/TBA201405090.shtml
# Greg Gibson: https://www.baseball-reference.com/boxes/TEX/TEX201405090.shtml
# Angel Hernandez: https://www.baseball-reference.com/boxes/TOR/TOR201405090.shtml
# Andy Fletcher: https://www.baseball-reference.com/boxes/ATL/ATL201405100.shtml
# Jeff Kellogg: https://www.baseball-reference.com/boxes/BAL/BAL201405100.shtml
# Phil Cuzzi: https://www.baseball-reference.com/boxes/CHA/CHA201405100.shtml
# Brian O'Nora: https://www.baseball-reference.com/boxes/CIN/CIN201405100.shtml
# Joe West: https://www.baseball-reference.com/boxes/DET/DET201405100.shtml
# Mark Carlson: https://www.baseball-reference.com/boxes/LAN/LAN201405100.shtml
# Paul Emmel: https://www.baseball-reference.com/boxes/MIL/MIL201405100.shtml
# Tim Timmons: https://www.baseball-reference.com/boxes/NYN/NYN201405100.shtml
# Kerwin Danley: https://www.baseball-reference.com/boxes/OAK/OAK201405100.shtml
# David Rackley: https://www.baseball-reference.com/boxes/PIT/PIT201405100.shtml
# Lance Barrett: https://www.baseball-reference.com/boxes/SDN/SDN201405100.shtml
# Scott Barry: https://www.baseball-reference.com/boxes/SEA/SEA201405100.shtml
# John Tumpane: https://www.baseball-reference.com/boxes/TBA/TBA201405100.shtml
# Bill Miller: https://www.baseball-reference.com/boxes/TEX/TEX201405100.shtml
# Adrian Johnson: https://www.baseball-reference.com/boxes/TOR/TOR201405100.shtml
# Seth Buckminster: https://www.baseball-reference.com/boxes/ATL/ATL201405110.shtml
# Tripp Gibson: https://www.baseball-reference.com/boxes/BAL/BAL201405110.shtml
# Quinn Wolcott: https://www.baseball-reference.com/boxes/CHA/CHA201405110.shtml
# Doug Eddings: https://www.baseball-reference.com/boxes/CIN/CIN201405110.shtml
# Clint Fagan: https://www.baseball-reference.com/boxes/DET/DET201405110.shtml
# Ted Barrett: https://www.baseball-reference.com/boxes/LAN/LAN201405110.shtml
# Tom Woodring: https://www.baseball-reference.com/boxes/MIL/MIL201405110.shtml
# Tim Welke: https://www.baseball-reference.com/boxes/NYN/NYN201405110.shtml
# Lance Barksdale: https://www.baseball-reference.com/boxes/OAK/OAK201405110.shtml
# Bill Welke: https://www.baseball-reference.com/boxes/PIT/PIT201405110.shtml
# Dana DeMuth: https://www.baseball-reference.com/boxes/SDN/SDN201405110.shtml
# Marcus Pattillo: https://www.baseball-reference.com/boxes/SEA/SEA201405110.shtml
# Paul Nauert: https://www.baseball-reference.com/boxes/TBA/TBA201405110.shtml
# Vic Carapazza: https://www.baseball-reference.com/boxes/TEX/TEX201405110.shtml
# Toby Basner: https://www.baseball-reference.com/boxes/TOR/TOR201405110.shtml
# Adam Hamari: https://www.baseball-reference.com/boxes/ARI/ARI201405120.shtml
# James Hoye: https://www.baseball-reference.com/boxes/BAL/BAL201405120.shtml
# Brian Gorman: https://www.baseball-reference.com/boxes/HOU/HOU201405120.shtml
# Gerry Davis: https://www.baseball-reference.com/boxes/LAN/LAN201405120.shtml
# Mike Estabrook: https://www.baseball-reference.com/boxes/NYA/NYA201405120.shtml
# Brian Knight: https://www.baseball-reference.com/boxes/OAK/OAK201405120.shtml
# Mark Ripperger: https://www.baseball-reference.com/boxes/SEA/SEA201405120.shtml
# Ron Kulpa: https://www.baseball-reference.com/boxes/SFN/SFN201405120.shtml
# Sean Barber: https://www.baseball-reference.com/boxes/SLN/SLN201405120.shtml
# Larry Vanover: https://www.baseball-reference.com/boxes/TOR/TOR201405120.shtml
# Jim Reynolds: https://www.baseball-reference.com/boxes/ARI/ARI201405130.shtml
# Bob Davidson: https://www.baseball-reference.com/boxes/BAL/BAL201405130.shtml
# Angel Hernandez: https://www.baseball-reference.com/boxes/CIN/CIN201405130.shtml
# David Rackley: https://www.baseball-reference.com/boxes/HOU/HOU201405130.shtml
# D.J. Reyburn: https://www.baseball-reference.com/boxes/KCA/KCA201405130.shtml
# Laz Diaz: https://www.baseball-reference.com/boxes/LAN/LAN201405130.shtml
# Dale Scott: https://www.baseball-reference.com/boxes/MIL/MIL201405130.shtml
# Tom Hallion: https://www.baseball-reference.com/boxes/MIN/MIN201405130.shtml
# Jerry Layne: https://www.baseball-reference.com/boxes/NYA/NYA201405130.shtml
# Fieldin Culbreth: https://www.baseball-reference.com/boxes/OAK/OAK201405130.shtml
# Marvin Hudson: https://www.baseball-reference.com/boxes/PHI/PHI201405130.shtml
# Gary Cederstrom: https://www.baseball-reference.com/boxes/SEA/SEA201405130.shtml
# Ed Hickox: https://www.baseball-reference.com/boxes/SFN/SFN201405130.shtml
# Paul Schrieber: https://www.baseball-reference.com/boxes/SLN/SLN201405130.shtml
# Jordan Baker: https://www.baseball-reference.com/boxes/TOR/TOR201405130.shtml
# Bill Miller: https://www.baseball-reference.com/boxes/ARI/ARI201405140.shtml
# John Tumpane: https://www.baseball-reference.com/boxes/BAL/BAL201405140.shtml
# Pat Hoberg: https://www.baseball-reference.com/boxes/HOU/HOU201405140.shtml
# Dan Bellino: https://www.baseball-reference.com/boxes/KCA/KCA201405140.shtml
# Scott Barry: https://www.baseball-reference.com/boxes/LAN/LAN201405140.shtml
# Dan Iassogna: https://www.baseball-reference.com/boxes/MIL/MIL201405140.shtml
# Eric Cooper: https://www.baseball-reference.com/boxes/MIN/MIN201405140.shtml
# Mike DiMuro: https://www.baseball-reference.com/boxes/NYN/NYN201405140.shtml
# Manny Gonzalez: https://www.baseball-reference.com/boxes/OAK/OAK201405140.shtml
# Cory Blaser: https://www.baseball-reference.com/boxes/PHI/PHI201405140.shtml
# Kerwin Danley: https://www.baseball-reference.com/boxes/SEA/SEA201405140.shtml
# Lance Barrett: https://www.baseball-reference.com/boxes/SFN/SFN201405140.shtml
# Jerry Meals: https://www.baseball-reference.com/boxes/TOR/TOR201405140.shtml
# Vic Carapazza: https://www.baseball-reference.com/boxes/ANA/ANA201405150.shtml
# Adrian Johnson: https://www.baseball-reference.com/boxes/CIN/CIN201405151.shtml
# Toby Basner: https://www.baseball-reference.com/boxes/CIN/CIN201405152.shtml
# Brian O'Nora: https://www.baseball-reference.com/boxes/KCA/KCA201405150.shtml
# CB Bucknor: https://www.baseball-reference.com/boxes/MIL/MIL201405150.shtml
# Chris Guccione: https://www.baseball-reference.com/boxes/MIN/MIN201405150.shtml
# Hunter Wendelstedt: https://www.baseball-reference.com/boxes/NYN/NYN201405150.shtml
# Lance Barksdale: https://www.baseball-reference.com/boxes/SFN/SFN201405150.shtml
# Will Little: https://www.baseball-reference.com/boxes/SLN/SLN201405150.shtml
# Paul Emmel: https://www.baseball-reference.com/boxes/TOR/TOR201405150.shtml
# Adam Hamari: https://www.baseball-reference.com/boxes/ANA/ANA201405160.shtml
# Jeff Kellogg: https://www.baseball-reference.com/boxes/ARI/ARI201405160.shtml
# Jeff Nelson: https://www.baseball-reference.com/boxes/BOS/BOS201405160.shtml
# Bill Welke: https://www.baseball-reference.com/boxes/CHN/CHN201405160.shtml
# Mike Estabrook: https://www.baseball-reference.com/boxes/CLE/CLE201405160.shtml
# Seth Buckminster: https://www.baseball-reference.com/boxes/COL/COL201405160.shtml
# Mark Carlson: https://www.baseball-reference.com/boxes/HOU/HOU201405160.shtml
# Doug Eddings: https://www.baseball-reference.com/boxes/KCA/KCA201405160.shtml
# Larry Vanover: https://www.baseball-reference.com/boxes/MIN/MIN201405160.shtml
# ...
# Lance Barrett: https://www.baseball-reference.com/boxes/CHA/CHA201405280.shtml
# Lance Barksdale: https://www.baseball-reference.com/boxes/KCA/KCA201405280.shtml
# Phil Cuzzi: https://www.baseball-reference.com/boxes/LAN/LAN201405280.shtml
# Jeff Kellogg: https://www.baseball-reference.com/boxes/MIL/MIL201405280.shtml
# Pat Hoberg: https://www.baseball-reference.com/boxes/MIN/MIN201405280.shtml
# Jeff Nelson: https://www.baseball-reference.com/boxes/NYN/NYN201405280.shtml
# Jerry Meals: https://www.baseball-reference.com/boxes/OAK/OAK201405280.shtml
# David Rackley: https://www.baseball-reference.com/boxes/PHI/PHI201405280.shtml
# Dale Scott: https://www.baseball-reference.com/boxes/SEA/SEA201405280.shtml
# Chris Segal: https://www.baseball-reference.com/boxes/SFN/SFN201405280.shtml
# Larry Vanover: https://www.baseball-reference.com/boxes/SLN/SLN201405280.shtml
# Brian O'Nora: https://www.baseball-reference.com/boxes/TOR/TOR201405280.shtml
# Seth Buckminster: https://www.baseball-reference.com/boxes/WAS/WAS201405280.shtml
# Mark Ripperger: https://www.baseball-reference.com/boxes/ARI/ARI201405290.shtml
# Bill Welke: https://www.baseball-reference.com/boxes/BOS/BOS201405290.shtml
# Mike Muchlinski: https://www.baseball-reference.com/boxes/HOU/HOU201405290.shtml
# Chris Guccione: https://www.baseball-reference.com/boxes/LAN/LAN201405290.shtml
# Jerry Layne: https://www.baseball-reference.com/boxes/MIN/MIN201405290.shtml
# Paul Emmel: https://www.baseball-reference.com/boxes/OAK/OAK201405290.shtml
# Doug Eddings: https://www.baseball-reference.com/boxes/PHI/PHI201405290.shtml
# Dan Iassogna: https://www.baseball-reference.com/boxes/SEA/SEA201405290.shtml
# Mike Everitt: https://www.baseball-reference.com/boxes/SLN/SLN201405290.shtml
# Angel Hernandez: https://www.baseball-reference.com/boxes/TOR/TOR201405290.shtml
# Gary Cederstrom: https://www.baseball-reference.com/boxes/ARI/ARI201405300.shtml
# Dan Bellino: https://www.baseball-reference.com/boxes/BOS/BOS201405300.shtml
# CB Bucknor: https://www.baseball-reference.com/boxes/CHA/CHA201405300.shtml
# John Tumpane: https://www.baseball-reference.com/boxes/CLE/CLE201405300.shtml
# Mark Wegner: https://www.baseball-reference.com/boxes/HOU/HOU201405300.shtml
# Paul Nauert: https://www.baseball-reference.com/boxes/LAN/LAN201405300.shtml
# Gerry Davis: https://www.baseball-reference.com/boxes/MIA/MIA201405300.shtml
# Jordan Baker: https://www.baseball-reference.com/boxes/MIL/MIL201405300.shtml
# Tony Randazzo: https://www.baseball-reference.com/boxes/NYA/NYA201405300.shtml
# Jim Reynolds: https://www.baseball-reference.com/boxes/OAK/OAK201405300.shtml
# Cory Blaser: https://www.baseball-reference.com/boxes/PHI/PHI201405300.shtml
# Mike DiMuro: https://www.baseball-reference.com/boxes/SEA/SEA201405300.shtml
# Ron Kulpa: https://www.baseball-reference.com/boxes/SLN/SLN201405300.shtml
# Adrian Johnson: https://www.baseball-reference.com/boxes/TOR/TOR201405300.shtml
# Scott Barry: https://www.baseball-reference.com/boxes/WAS/WAS201405300.shtml
# Kerwin Danley: https://www.baseball-reference.com/boxes/ARI/ARI201405310.shtml
# Ted Barrett: https://www.baseball-reference.com/boxes/BOS/BOS201405310.shtml
# Tripp Gibson: https://www.baseball-reference.com/boxes/CHA/CHA201405310.shtml
# Bob Davidson: https://www.baseball-reference.com/boxes/CLE/CLE201405310.shtml
# Andy Fletcher: https://www.baseball-reference.com/boxes/HOU/HOU201405310.shtml
# Eric Cooper: https://www.baseball-reference.com/boxes/LAN/LAN201405310.shtml
# Quinn Wolcott: https://www.baseball-reference.com/boxes/MIA/MIA201405310.shtml
# Angel Campos: https://www.baseball-reference.com/boxes/MIL/MIL201405310.shtml
# Jim Wolf: https://www.baseball-reference.com/boxes/NYA/NYA201405310.shtml
# Brian Knight: https://www.baseball-reference.com/boxes/OAK/OAK201405310.shtml
# Marvin Hudson: https://www.baseball-reference.com/boxes/PHI/PHI201405310.shtml
# Mike Estabrook: https://www.baseball-reference.com/boxes/SEA/SEA201405310.shtml
# Marcus Pattillo: https://www.baseball-reference.com/boxes/SLN/SLN201405310.shtml
# Gabe Morales: https://www.baseball-reference.com/boxes/TOR/TOR201405310.shtml
# Laz Diaz: https://www.baseball-reference.com/boxes/WAS/WAS201405310.shtml
# Lance Barksdale: https://www.baseball-reference.com/boxes/ARI/ARI201406010.shtml
# D.J. Reyburn: https://www.baseball-reference.com/boxes/BOS/BOS201406010.shtml
# Dale Scott: https://www.baseball-reference.com/boxes/CHA/CHA201406010.shtml
# James Hoye: https://www.baseball-reference.com/boxes/CLE/CLE201406010.shtml
# Chris Segal: https://www.baseball-reference.com/boxes/HOU/HOU201406010.shtml
# Sean Barber: https://www.baseball-reference.com/boxes/LAN/LAN201406010.shtml
# Greg Gibson: https://www.baseball-reference.com/boxes/MIA/MIA201406010.shtml
# Jerry Meals: https://www.baseball-reference.com/boxes/MIL/MIL201406010.shtml
# Brian Gorman: https://www.baseball-reference.com/boxes/NYA/NYA201406010.shtml
# Fieldin Culbreth: https://www.baseball-reference.com/boxes/OAK/OAK201406010.shtml
# Brian O'Nora: https://www.baseball-reference.com/boxes/PHI/PHI201406010.shtml
# Hunter Wendelstedt: https://www.baseball-reference.com/boxes/SEA/SEA201406010.shtml
# Lance Barrett: https://www.baseball-reference.com/boxes/SLN/SLN201406010.shtml
# Larry Vanover: https://www.baseball-reference.com/boxes/TOR/TOR201406010.shtml
# Clint Fagan: https://www.baseball-reference.com/boxes/WAS/WAS201406010.shtml
# Phil Cuzzi: https://www.baseball-reference.com/boxes/CLE/CLE201406020.shtml
# Mark Ripperger: https://www.baseball-reference.com/boxes/LAN/LAN201406020.shtml
# Bill Miller: https://www.baseball-reference.com/boxes/MIA/MIA201406020.shtml
# Mike Muchlinski: https://www.baseball-reference.com/boxes/MIL/MIL201406020.shtml
# David Rackley: https://www.baseball-reference.com/boxes/NYA/NYA201406020.shtml
# Pat Hoberg: https://www.baseball-reference.com/boxes/PHI/PHI201406020.shtml
# Seth Buckminster: https://www.baseball-reference.com/boxes/SDN/SDN201406020.shtml
# Dan Iassogna: https://www.baseball-reference.com/boxes/SLN/SLN201406020.shtml
# Paul Schrieber: https://www.baseball-reference.com/boxes/ATL/ATL201406030.shtml
# Tim Welke: https://www.baseball-reference.com/boxes/CHN/CHN201406030.shtml
# Angel Hernandez: https://www.baseball-reference.com/boxes/CIN/CIN201406030.shtml
# Gerry Davis: https://www.baseball-reference.com/boxes/CLE/CLE201406030.shtml
# Jerry Layne: https://www.baseball-reference.com/boxes/COL/COL201406030.shtml
# Tony Randazzo: https://www.baseball-reference.com/boxes/DET/DET201406030.shtml
# Paul Emmel: https://www.baseball-reference.com/boxes/HOU/HOU201406030.shtml
# Gary Cederstrom: https://www.baseball-reference.com/boxes/LAN/LAN201406030.shtml
# Vic Carapazza: https://www.baseball-reference.com/boxes/MIA/MIA201406030.shtml
# Mark Wegner: https://www.baseball-reference.com/boxes/MIL/MIL201406030.shtml
# Chris Guccione: https://www.baseball-reference.com/boxes/NYA/NYA201406030.shtml
# Alan Porter: https://www.baseball-reference.com/boxes/SDN/SDN201406030.shtml
# CB Bucknor: https://www.baseball-reference.com/boxes/SLN/SLN201406030.shtml
# Manny Gonzalez: https://www.baseball-reference.com/boxes/TEX/TEX201406030.shtml
# Mike Everitt: https://www.baseball-reference.com/boxes/WAS/WAS201406030.shtml
# Marty Foster: https://www.baseball-reference.com/boxes/ATL/ATL201406040.shtml
# Todd Tichenor: https://www.baseball-reference.com/boxes/CHN/CHN201406040.shtml
# Adrian Johnson: https://www.baseball-reference.com/boxes/CIN/CIN201406040.shtml
# Quinn Wolcott: https://www.baseball-reference.com/boxes/CLE/CLE201406040.shtml
# Mike DiMuro: https://www.baseball-reference.com/boxes/COL/COL201406040.shtml
# Jim Wolf: https://www.baseball-reference.com/boxes/DET/DET201406040.shtml
# Jordan Baker: https://www.baseball-reference.com/boxes/HOU/HOU201406040.shtml
# Tripp Gibson: https://www.baseball-reference.com/boxes/KCA/KCA201406040.shtml
# Kerwin Danley: https://www.baseball-reference.com/boxes/LAN/LAN201406040.shtml
# Andy Fletcher: https://www.baseball-reference.com/boxes/MIN/MIN201406040.shtml
# Paul Nauert: https://www.baseball-reference.com/boxes/NYA/NYA201406040.shtml
# Joe West: https://www.baseball-reference.com/boxes/SDN/SDN201406040.shtml
# Adam Hamari: https://www.baseball-reference.com/boxes/TBA/TBA201406040.shtml
# Jim Reynolds: https://www.baseball-reference.com/boxes/TEX/TEX201406040.shtml
# Ed Hickox: https://www.baseball-reference.com/boxes/WAS/WAS201406040.shtml
# Clint Fagan: https://www.baseball-reference.com/boxes/CHN/CHN201406050.shtml
# Gabe Morales: https://www.baseball-reference.com/boxes/CIN/CIN201406050.shtml
# Mike Estabrook: https://www.baseball-reference.com/boxes/COL/COL201406050.shtml
# David Rackley: https://www.baseball-reference.com/boxes/DET/DET201406050.shtml
# Angel Campos: https://www.baseball-reference.com/boxes/HOU/HOU201406050.shtml
# Dale Scott: https://www.baseball-reference.com/boxes/KCA/KCA201406050.shtml
# Chris Segal: https://www.baseball-reference.com/boxes/MIN/MIN201406050.shtml
# Tom Hallion: https://www.baseball-reference.com/boxes/NYA/NYA201406050.shtml
# Chris Conroy: https://www.baseball-reference.com/boxes/TBA/TBA201406050.shtml
# Lance Barrett: https://www.baseball-reference.com/boxes/TEX/TEX201406050.shtml
# Ron Kulpa: https://www.baseball-reference.com/boxes/WAS/WAS201406050.shtml
# Greg Gibson: https://www.baseball-reference.com/boxes/ANA/ANA201406060.shtml
# Mike Muchlinski: https://www.baseball-reference.com/boxes/ARI/ARI201406060.shtml
# Larry Vanover: https://www.baseball-reference.com/boxes/BAL/BAL201406060.shtml
# Brian Gorman: https://www.baseball-reference.com/boxes/CHN/CHN201406060.shtml
# Sean Barber: https://www.baseball-reference.com/boxes/CIN/CIN201406060.shtml
# Dan Iassogna: https://www.baseball-reference.com/boxes/COL/COL201406060.shtml
# Bill Miller: https://www.baseball-reference.com/boxes/DET/DET201406060.shtml
# Bob Davidson: https://www.baseball-reference.com/boxes/KCA/KCA201406060.shtml
# Will Little: https://www.baseball-reference.com/boxes/MIN/MIN201406060.shtml
# John Tumpane: https://www.baseball-reference.com/boxes/PIT/PIT201406060.shtml
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# /anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# /anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# TimeoutError: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x11dc34d68>: Failed to establish a new connection: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# /anaconda3/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='www.baseball-reference.com', port=443): Max retries exceeded with url: /boxes/SDN/SDN201406060.shtml (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x11dc34d68>: Failed to establish a new connection: [Errno 60] Operation timed out'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-3-8aa0080e55c4> in <module>
#       8 for url in games_2014:
#       9     # Load the html from the game page
# ---> 10     response = requests.get(url)
#      11     html = response.text
#      12     html = html.replace('<!--', '').replace('-->', '')
#
# /anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.baseball-reference.com', port=443): Max retries exceeded with url: /boxes/SDN/SDN201406060.shtml (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x11dc34d68>: Failed to establish a new connection: [Errno 60] Operation timed out'))

# %%
# This is meant to be run as a cell
# Set the list of the games to get here
game_list = games_2014

# Here is the big for loop which populates df_list with 
for i in range(len(df_list),len(game_list)):
    # Load the html from the game page
    response = requests.get(game_list[i])
    html = response.text
    html = html.replace('<!--', '').replace('-->', '')

    # Find the umpire name for the game
    ump_name = get_ump(html)
    
    # Do everything else here
    soup = BeautifulSoup(html, 'html.parser')

    pbp_table = soup.find('table', id='play_by_play')

    events = pbp_table.find_all('tr', {'class':['top_inning', 'bottom_inning']})
    
    for x in range(len(events)):
        try:
            x += 1
            if events[x].find(attrs={"data-stat": "batter"}).get_text() == events[x-1].find(attrs={"data-stat": "batter"}).get_text():
                events.pop(x-1)
                x -= 1
        except:
            break

        data_dict = {}
        pitch = []
        balls = []
        strikes = []
        count = []
        pitchers = []x`
        batters = []
        home_pitcher = []
        innings = []
        run_diffs = []
        umps = []

    for e in events:
        strike_codes = ['C', 'S', 'T', 'K', 'L', 'M', 'O', 'Q', 'R']
        foul_code = 'F'
        ball_codes = ['B', 'I', 'P', 'V']
        
        try:
            pit_seq = e.find('span', 'pitch_sequence').get_text()
            pit_seq = re.sub('[^CSFBXTKIHLMOPQRVY]', '', pit_seq)
            pit_seq = list(pit_seq)

            ball_count = 0
            strike_count = 0
            
            for pit in pit_seq:
                batter = e.find(attrs={"data-stat": "batter"}).get_text()
                pitcher = e.find(attrs={"data-stat": "pitcher"}).get_text()
                inning = e.find(attrs={"data-stat": "inning"}).get_text()
                score = e.find(attrs={"data-stat": "score_batting_team"}).get_text()

                ball_strike_count = f'{ball_count}-{strike_count}'
                
                bat_score, pit_score = score.split('-', 1)  
                run_diff = int(pit_score) - int(bat_score)
                
                top_bottom = list(inning)[0]
                
                if top_bottom == 't':
                    pitcher_home = 1
                else:
                    pitcher_home = 0
                    
                if len(list(inning)) > 2:
                    inning_num = int(list(inning)[1] + list(inning)[2])
                else:
                    inning_num = int(list(inning)[1])
                
                pitch.append(pit)
                balls.append(ball_count)
                strikes.append(strike_count)
                count.append(ball_strike_count)
                batters.append(batter)
                pitchers.append(pitcher)
                umps.append(ump_name)
                home_pitcher.append(pitcher_home)
                innings.append(inning_num)
                run_diffs.append(run_diff)
                
                if pit in strike_codes:
                    strike_count += 1
                elif pit == foul_code and strike_count < 2:
                    strike_count += 1
                elif pit in ball_codes:
                    ball_count += 1
                
        except Exception as exception:
            print(f'{exception}: {url}')
            pit_seq = None
    
    # Populate data dictionary and DataFrame
    data_dict["pitch"] = pitch
    data_dict["balls"] = balls
    data_dict["strikes"] = strikes
    data_dict["count"] = count
    data_dict["batter"] = batters
    data_dict["pitcher"] = pitchers
    data_dict["umpire"] = umps
    data_dict["home_pitcher"] = home_pitcher
    data_dict["inning"] = innings
    data_dict["run_diff"] = run_diffs

    df = pd.DataFrame(data_dict)
    
    df_list.append(df)

# %%
pitches_df = pd.concat(df_list)
pitches_df
# Out:
#     pitch  balls  strikes count            batter            pitcher  \
# 0       C      0        0   0-0       Yasiel Puig         Wade Miley
# 1       F      0        1   0-1       Yasiel Puig         Wade Miley
# 2       S      0        2   0-2       Yasiel Puig         Wade Miley
# 3       B      0        0   0-0     Justin Turner         Wade Miley
# 4       B      1        0   1-0     Justin Turner         Wade Miley
# 5       F      2        0   2-0     Justin Turner         Wade Miley
# 6       S      2        1   2-1     Justin Turner         Wade Miley
# 7       C      2        2   2-2     Justin Turner         Wade Miley
# 8       S      0        0   0-0    Hanley Ramirez         Wade Miley
# 9       B      0        1   0-1    Hanley Ramirez         Wade Miley
# 10      S      1        1   1-1    Hanley Ramirez         Wade Miley
# 11      B      1        2   1-2    Hanley Ramirez         Wade Miley
# 12      X      2        2   2-2    Hanley Ramirez         Wade Miley
# 13      C      0        0   0-0      A.J. Pollock    Clayton Kershaw
# 14      S      0        1   0-1      A.J. Pollock    Clayton Kershaw
# 15      C      0        2   0-2      A.J. Pollock    Clayton Kershaw
# 16      B      0        0   0-0        Aaron Hill    Clayton Kershaw
# 17      C      1        0   1-0        Aaron Hill    Clayton Kershaw
# 18      S      1        1   1-1        Aaron Hill    Clayton Kershaw
# 19      X      1        2   1-2        Aaron Hill    Clayton Kershaw
# 20      B      0        0   0-0  Paul Goldschmidt    Clayton Kershaw
# 21      X      1        0   1-0  Paul Goldschmidt    Clayton Kershaw
# 22      C      0        0   0-0      Martin Prado    Clayton Kershaw
# 23      B      0        1   0-1      Martin Prado    Clayton Kershaw
# 24      X      1        1   1-1      Martin Prado    Clayton Kershaw
# 25      B      0        0   0-0       Mark Trumbo    Clayton Kershaw
# 26      B      1        0   1-0       Mark Trumbo    Clayton Kershaw
# 27      C      2        0   2-0       Mark Trumbo    Clayton Kershaw
# 28      X      2        1   2-1       Mark Trumbo    Clayton Kershaw
# 29      B      0        0   0-0   Adrian Gonzalez         Wade Miley
# ..    ...    ...      ...   ...               ...                ...
# 218     X      2        2   2-2      Lorenzo Cain  Madison Bumgarner
# 219     S      0        0   0-0      Brandon Belt       Greg Holland
# 220     B      0        1   0-1      Brandon Belt       Greg Holland
# 221     X      1        1   1-1      Brandon Belt       Greg Holland
# 222     S      0        0   0-0        Mike Morse       Greg Holland
# 223     S      0        1   0-1        Mike Morse       Greg Holland
# 224     B      0        2   0-2        Mike Morse       Greg Holland
# 225     S      1        2   1-2        Mike Morse       Greg Holland
# 226     B      0        0   0-0  Brandon Crawford       Greg Holland
# 227     B      1        0   1-0  Brandon Crawford       Greg Holland
# 228     S      2        0   2-0  Brandon Crawford       Greg Holland
# 229     F      2        1   2-1  Brandon Crawford       Greg Holland
# 230     B      2        2   2-2  Brandon Crawford       Greg Holland
# 231     S      3        2   3-2  Brandon Crawford       Greg Holland
# 232     B      0        0   0-0       Eric Hosmer  Madison Bumgarner
# 233     B      1        0   1-0       Eric Hosmer  Madison Bumgarner
# 234     C      2        0   2-0       Eric Hosmer  Madison Bumgarner
# 235     F      2        1   2-1       Eric Hosmer  Madison Bumgarner
# 236     S      2        2   2-2       Eric Hosmer  Madison Bumgarner
# 237     B      0        0   0-0      Billy Butler  Madison Bumgarner
# 238     C      1        0   1-0      Billy Butler  Madison Bumgarner
# 239     X      1        1   1-1      Billy Butler  Madison Bumgarner
# 240     F      0        0   0-0       Alex Gordon  Madison Bumgarner
# 241     X      0        1   0-1       Alex Gordon  Madison Bumgarner
# 242     S      0        0   0-0    Salvador Perez  Madison Bumgarner
# 243     B      0        1   0-1    Salvador Perez  Madison Bumgarner
# 244     S      1        1   1-1    Salvador Perez  Madison Bumgarner
# 245     B      1        2   1-2    Salvador Perez  Madison Bumgarner
# 246     F      2        2   2-2    Salvador Perez  Madison Bumgarner
# 247     X      2        2   2-2    Salvador Perez  Madison Bumgarner
#
#           umpire  home_pitcher  inning  run_diff
# 0      Tim Welke             1       1         0
# 1      Tim Welke             1       1         0
# 2      Tim Welke             1       1         0
# 3      Tim Welke             1       1         0
# 4      Tim Welke             1       1         0
# 5      Tim Welke             1       1         0
# 6      Tim Welke             1       1         0
# 7      Tim Welke             1       1         0
# 8      Tim Welke             1       1         0
# 9      Tim Welke             1       1         0
# 10     Tim Welke             1       1         0
# 11     Tim Welke             1       1         0
# 12     Tim Welke             1       1         0
# 13     Tim Welke             0       1         0
# 14     Tim Welke             0       1         0
# 15     Tim Welke             0       1         0
# 16     Tim Welke             0       1         0
# 17     Tim Welke             0       1         0
# 18     Tim Welke             0       1         0
# 19     Tim Welke             0       1         0
# 20     Tim Welke             0       1         0
# 21     Tim Welke             0       1         0
# 22     Tim Welke             0       1         0
# 23     Tim Welke             0       1         0
# 24     Tim Welke             0       1         0
# 25     Tim Welke             0       1         0
# 26     Tim Welke             0       1         0
# 27     Tim Welke             0       1         0
# 28     Tim Welke             0       1         0
# 29     Tim Welke             1       2         0
# ..           ...           ...     ...       ...
# 218  Jeff Nelson             0       8         1
# 219  Jeff Nelson             1       9        -1
# 220  Jeff Nelson             1       9        -1
# 221  Jeff Nelson             1       9        -1
# 222  Jeff Nelson             1       9        -1
# 223  Jeff Nelson             1       9        -1
# 224  Jeff Nelson             1       9        -1
# 225  Jeff Nelson             1       9        -1
# 226  Jeff Nelson             1       9        -1
# 227  Jeff Nelson             1       9        -1
# 228  Jeff Nelson             1       9        -1
# 229  Jeff Nelson             1       9        -1
# 230  Jeff Nelson             1       9        -1
# 231  Jeff Nelson             1       9        -1
# 232  Jeff Nelson             0       9         1
# 233  Jeff Nelson             0       9         1
# 234  Jeff Nelson             0       9         1
# 235  Jeff Nelson             0       9         1
# 236  Jeff Nelson             0       9         1
# 237  Jeff Nelson             0       9         1
# 238  Jeff Nelson             0       9         1
# 239  Jeff Nelson             0       9         1
# 240  Jeff Nelson             0       9         1
# 241  Jeff Nelson             0       9         1
# 242  Jeff Nelson             0       9         1
# 243  Jeff Nelson             0       9         1
# 244  Jeff Nelson             0       9         1
# 245  Jeff Nelson             0       9         1
# 246  Jeff Nelson             0       9         1
# 247  Jeff Nelson             0       9         1
#
# [714766 rows x 10 columns]

# %%
len(df_list)
# Out:
# 2462

# %%
len(games_2014)
# Out:
# 2462

# %%
pitches_df.to_csv("games_2014.csv")

# %%
games_2013_url = 'https://www.baseball-reference.com/leagues/MLB/2013-schedule.shtml'
games_2013 = get_games(games_2013_url)

df_list = []

# %%
# This is meant to be run as a cell
# Set the list of the games to get here
game_list = games_2013

# Here is the big for loop which populates df_list with 
for i in range(len(df_list),len(game_list)):
    # Load the html from the game page
    response = requests.get(game_list[i])
    html = response.text
    html = html.replace('<!--', '').replace('-->', '')

    # Find the umpire name for the game
    ump_name = get_ump(html)
    
    # Do everything else here
    soup = BeautifulSoup(html, 'html.parser')

    pbp_table = soup.find('table', id='play_by_play')

    events = pbp_table.find_all('tr', {'class':['top_inning', 'bottom_inning']})
    
    for x in range(len(events)):
        try:
            x += 1
            if events[x].find(attrs={"data-stat": "batter"}).get_text() == events[x-1].find(attrs={"data-stat": "batter"}).get_text():
                events.pop(x-1)
                x -= 1
        except:
            break

        data_dict = {}
        pitch = []
        balls = []
        strikes = []
        count = []
        pitchers = []
        batters = []
        home_pitcher = []
        innings = []
        run_diffs = []
        umps = []

    for e in events:
        strike_codes = ['C', 'S', 'T', 'K', 'L', 'M', 'O', 'Q', 'R']
        foul_code = 'F'
        ball_codes = ['B', 'I', 'P', 'V']
        
        try:
            pit_seq = e.find('span', 'pitch_sequence').get_text()
            pit_seq = re.sub('[^CSFBXTKIHLMOPQRVY]', '', pit_seq)
            pit_seq = list(pit_seq)

            ball_count = 0
            strike_count = 0
            
            for pit in pit_seq:
                batter = e.find(attrs={"data-stat": "batter"}).get_text()
                pitcher = e.find(attrs={"data-stat": "pitcher"}).get_text()
                inning = e.find(attrs={"data-stat": "inning"}).get_text()
                score = e.find(attrs={"data-stat": "score_batting_team"}).get_text()

                ball_strike_count = f'{ball_count}-{strike_count}'
                
                bat_score, pit_score = score.split('-', 1)  
                run_diff = int(pit_score) - int(bat_score)
                
                top_bottom = list(inning)[0]
                
                if top_bottom == 't':
                    pitcher_home = 1
                else:
                    pitcher_home = 0
                    
                if len(list(inning)) > 2:
                    inning_num = int(list(inning)[1] + list(inning)[2])
                else:
                    inning_num = int(list(inning)[1])
                
                pitch.append(pit)
                balls.append(ball_count)
                strikes.append(strike_count)
                count.append(ball_strike_count)
                batters.append(batter)
                pitchers.append(pitcher)
                umps.append(ump_name)
                home_pitcher.append(pitcher_home)
                innings.append(inning_num)
                run_diffs.append(run_diff)
                
                if pit in strike_codes:
                    strike_count += 1
                elif pit == foul_code and strike_count < 2:
                    strike_count += 1
                elif pit in ball_codes:
                    ball_count += 1
                
        except Exception as exception:
            print(f'{exception}: {url}')
            pit_seq = None
    
    # Populate data dictionary and DataFrame
    data_dict["pitch"] = pitch
    data_dict["balls"] = balls
    data_dict["strikes"] = strikes
    data_dict["count"] = count
    data_dict["batter"] = batters
    data_dict["pitcher"] = pitchers
    data_dict["umpire"] = umps
    data_dict["home_pitcher"] = home_pitcher
    data_dict["inning"] = innings
    data_dict["run_diff"] = run_diffs

    df = pd.DataFrame(data_dict)
    
    df_list.append(df)

# %%
len(df_list)
# Out:
# 2469

# %%
pitches_df = pd.concat(df_list)

# %%
pitches_df.to_csv("games_2013.csv")

# %%
games_2015_url = 'https://www.baseball-reference.com/leagues/MLB/2015-schedule.shtml'
games_2015 = get_games(games_2015_url)

df_list = []

# %%
# This is meant to be run as a cell
# Set the list of the games to get here
game_list = games_2015

# Here is the big for loop which populates df_list with 
for i in range(len(df_list),len(game_list)):
    # Load the html from the game page
    response = requests.get(game_list[i])
    html = response.text
    html = html.replace('<!--', '').replace('-->', '')

    # Find the umpire name for the game
    ump_name = get_ump(html)
    
    # Do everything else here
    soup = BeautifulSoup(html, 'html.parser')

    pbp_table = soup.find('table', id='play_by_play')

    events = pbp_table.find_all('tr', {'class':['top_inning', 'bottom_inning']})
    
    for x in range(len(events)):
        try:
            x += 1
            if events[x].find(attrs={"data-stat": "batter"}).get_text() == events[x-1].find(attrs={"data-stat": "batter"}).get_text():
                events.pop(x-1)
                x -= 1
        except:
            break

        data_dict = {}
        pitch = []
        balls = []
        strikes = []
        count = []
        pitchers = []
        batters = []
        home_pitcher = []
        innings = []
        run_diffs = []
        umps = []

    for e in events:
        strike_codes = ['C', 'S', 'T', 'K', 'L', 'M', 'O', 'Q', 'R']
        foul_code = 'F'
        ball_codes = ['B', 'I', 'P', 'V']
        
        try:
            pit_seq = e.find('span', 'pitch_sequence').get_text()
            pit_seq = re.sub('[^CSFBXTKIHLMOPQRVY]', '', pit_seq)
            pit_seq = list(pit_seq)

            ball_count = 0
            strike_count = 0
            
            for pit in pit_seq:
                batter = e.find(attrs={"data-stat": "batter"}).get_text()
                pitcher = e.find(attrs={"data-stat": "pitcher"}).get_text()
                inning = e.find(attrs={"data-stat": "inning"}).get_text()
                score = e.find(attrs={"data-stat": "score_batting_team"}).get_text()

                ball_strike_count = f'{ball_count}-{strike_count}'
                
                bat_score, pit_score = score.split('-', 1)  
                run_diff = int(pit_score) - int(bat_score)
                
                top_bottom = list(inning)[0]
                
                if top_bottom == 't':
                    pitcher_home = 1
                else:
                    pitcher_home = 0
                    
                if len(list(inning)) > 2:
                    inning_num = int(list(inning)[1] + list(inning)[2])
                else:
                    inning_num = int(list(inning)[1])
                
                pitch.append(pit)
                balls.append(ball_count)
                strikes.append(strike_count)
                count.append(ball_strike_count)
                batters.append(batter)
                pitchers.append(pitcher)
                umps.append(ump_name)
                home_pitcher.append(pitcher_home)
                innings.append(inning_num)
                run_diffs.append(run_diff)
                
                if pit in strike_codes:
                    strike_count += 1
                elif pit == foul_code and strike_count < 2:
                    strike_count += 1
                elif pit in ball_codes:
                    ball_count += 1
                
        except Exception as exception:
            print(f'{exception}: {url}')
            pit_seq = None
    
    # Populate data dictionary and DataFrame
    data_dict["pitch"] = pitch
    data_dict["balls"] = balls
    data_dict["strikes"] = strikes
    data_dict["count"] = count
    data_dict["batter"] = batters
    data_dict["pitcher"] = pitchers
    data_dict["umpire"] = umps
    data_dict["home_pitcher"] = home_pitcher
    data_dict["inning"] = innings
    data_dict["run_diff"] = run_diffs

    df = pd.DataFrame(data_dict)
    
    df_list.append(df)

# %%
pitches_df = pd.concat(df_list)

# %%
pitches_df.to_csv("games_2015.csv")
